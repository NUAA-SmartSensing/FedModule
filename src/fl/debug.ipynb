# %%
import pandas as pd

# %%
orbit_info = pd.read_csv("../access/walker_delta_orbit_info.csv") 
# orbit_info['Orbit'].drop_duplicates().count()
orbit_info['Orbit'].nunique()
orbit_info
# Out:
#     client_id          Source  Orbit
# 0           0   WalkerDelta_1      0
# 1           1  WalkerDelta_10      0
# 2           2  WalkerDelta_11      0
# 3           3   WalkerDelta_2      0
# 4           4   WalkerDelta_3      0
# ..        ...             ...    ...
# 61         61  WalkerDelta_62      5
# 62         62  WalkerDelta_63      5
# 63         63  WalkerDelta_64      5
# 64         64  WalkerDelta_65      5
# 65         65  WalkerDelta_66      5
#
# [66 rows x 3 columns]
